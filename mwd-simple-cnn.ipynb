# %%
#imports
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

import os
import re
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.callbacks import Callback, EarlyStopping
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.utils import plot_model
from skimage import io, color, transform
from tqdm import tqdm
from collections import Counter
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, Adamax
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# %%
# constants - folder, resizing factor, file extensions to be handled
image_folder = '/kaggle/input/multiclass-weather-dataset/Multi-class Weather Dataset'
size_fact = 64
img_width, img_height, channels = size_fact, size_fact, 3
file_extensions = ['.jpg', '.jpeg'] # since some images were of type .jpeg

# %%
# create class labels and image counts
def count_images_in_subfolders(folder_path):
    class_labels = []
    image_counts = []

    if not os.path.exists(folder_path): # check for folder
        print("Folder does not exist.") 
        return class_labels, image_counts

    subfolders = [subfolder for subfolder in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, subfolder))]

    for subfolder in subfolders:
        # check for both .jpg and .jpeg since there are some .jpeg files as well
        jpg_count = len([filename for filename in os.listdir(os.path.join(folder_path, subfolder)) if filename.lower().endswith(('.jpg', '.jpeg'))])
        class_labels.append(subfolder)
        image_counts.append(jpg_count)

    return class_labels, image_counts

# run for image folder
classes, num_images_per_class = count_images_in_subfolders(image_folder)

print(classes)
print(num_images_per_class)
# Out:
# ['Cloudy', 'Sunrise', 'Rain', 'Shine']
# [300, 357, 215, 253]

# %%
# rearrange for better representation and following the input data order (this step is optional)
def list_rearrange(listname):
    second_item = listname.pop(1)
    listname.append(second_item)

list_rearrange(classes)
list_rearrange(num_images_per_class)

print(classes)
print(num_images_per_class)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']
# [300, 215, 253, 357]

# %%
images = []
labels = []
def load_and_preprocess_images(folder_path, num_images_per_class, file_extensions=['.jpg', '.jpeg']):

    for class_idx, class_name in enumerate(classes):
        class_folder = os.path.join(folder_path, class_name)

        for dirpath, dirnames, filenames in os.walk(class_folder):
            for i in tqdm(range(1, num_images_per_class[class_idx] + 1), desc=f'Loading {class_name} images'):
                for extension in file_extensions:
                    for filename in filenames:
                        if filename.startswith(f'{class_name.lower()}{i}') and filename.endswith(extension):
                            image_path = os.path.join(dirpath, filename)

                            image = io.imread(image_path)
                            
                            # conditional formatting
                            if image.shape[-1] == 4:
                                image = image[:, :, :3]
                            elif len(image.shape) == 2:
                                image = color.gray2rgb(image)
                            elif len(image.shape) == 4:
                                image = image[0]

                            image = transform.resize(image, (img_width, img_height))
                            images.append(image)
                            labels.append(class_idx)
                            
                            break

    return np.array(images), np.array(labels)

images, labels = load_and_preprocess_images(image_folder, num_images_per_class, file_extensions)
# Out:
# Loading Cloudy images: 100%|██████████| 300/300 [00:12<00:00, 23.90it/s]
# Loading Rain images: 100%|██████████| 215/215 [00:48<00:00,  4.40it/s]
# Loading Shine images: 100%|██████████| 253/253 [00:14<00:00, 17.04it/s]
# Loading Sunrise images: 100%|██████████| 357/357 [00:55<00:00,  6.40it/s]

# %%
# data splitting
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, shuffle=True, random_state=42)

# hyperparameters for training
epochs = 75
batch_size = 200
# callback for early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# %%
# model architecture - basic CNN
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, channels)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(classes), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# model arhcitecture summary and plot (graphviz is needed to be installed for plot_model to work)
model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 683,716
# Trainable params: 683,716
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Check if GPU is available
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("No GPU Found")
# Out:
# Default GPU Device: /device:GPU:0

# %%
# Training the model
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.15, callbacks=[early_stop])
print("Training completed")
# Out:
# Epoch 1/75
# 4/4 [==============================] - 12s 289ms/step - loss: 1.3506 - accuracy: 0.3386 - val_loss: 1.2189 - val_accuracy: 0.5809
# Epoch 2/75
# 4/4 [==============================] - 0s 35ms/step - loss: 1.0927 - accuracy: 0.5281 - val_loss: 0.8600 - val_accuracy: 0.6250
# Epoch 3/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.8742 - accuracy: 0.5830 - val_loss: 0.7130 - val_accuracy: 0.7721
# Epoch 4/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.7660 - accuracy: 0.6667 - val_loss: 0.6243 - val_accuracy: 0.7868
# Epoch 5/75
# 4/4 [==============================] - 0s 38ms/step - loss: 0.7297 - accuracy: 0.6850 - val_loss: 0.5481 - val_accuracy: 0.8235
# Epoch 6/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6897 - accuracy: 0.7098 - val_loss: 0.5163 - val_accuracy: 0.8015
# Epoch 7/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6514 - accuracy: 0.7268 - val_loss: 0.5026 - val_accuracy: 0.8162
# Epoch 8/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.6063 - accuracy: 0.7634 - val_loss: 0.4948 - val_accuracy: 0.8235
# Epoch 9/75
# 4/4 [==============================] - 0s 37ms/step - loss: 0.5770 - accuracy: 0.7817 - val_loss: 0.4462 - val_accuracy: 0.8382
# Epoch 10/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.5557 - accuracy: 0.7856 - val_loss: 0.4235 - val_accuracy: 0.8750
# Epoch 11/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5171 - accuracy: 0.8065 - val_loss: 0.4020 - val_accuracy: 0.8309
# Epoch 12/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4886 - accuracy: 0.7987 - val_loss: 0.4290 - val_accuracy: 0.8529
# Epoch 13/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4766 - accuracy: 0.8170 - val_loss: 0.3814 - val_accuracy: 0.8897
# Epoch 14/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4499 - accuracy: 0.8444 - val_loss: 0.3483 - val_accuracy: 0.8897
# Epoch 15/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4065 - accuracy: 0.8484 - val_loss: 0.3601 - val_accuracy: 0.8676
# Epoch 16/75
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3871 - accuracy: 0.8627 - val_loss: 0.3039 - val_accuracy: 0.8971
# Epoch 17/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3548 - accuracy: 0.8680 - val_loss: 0.3328 - val_accuracy: 0.8824
# Epoch 18/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3403 - accuracy: 0.8706 - val_loss: 0.3330 - val_accuracy: 0.8897
# Epoch 19/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3796 - accuracy: 0.8588 - val_loss: 0.3392 - val_accuracy: 0.9044
# Epoch 20/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3582 - accuracy: 0.8797 - val_loss: 0.3300 - val_accuracy: 0.8750
# Epoch 21/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3723 - accuracy: 0.8458 - val_loss: 0.3706 - val_accuracy: 0.8456
# Epoch 22/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3433 - accuracy: 0.8719 - val_loss: 0.3433 - val_accuracy: 0.8750
# Epoch 23/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3406 - accuracy: 0.8641 - val_loss: 0.2637 - val_accuracy: 0.9338
# Epoch 24/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2804 - accuracy: 0.8915 - val_loss: 0.2995 - val_accuracy: 0.8824
# Epoch 25/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2826 - accuracy: 0.8915 - val_loss: 0.2524 - val_accuracy: 0.9412
# Epoch 26/75
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2705 - accuracy: 0.8980 - val_loss: 0.2613 - val_accuracy: 0.9191
# Epoch 27/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2518 - accuracy: 0.9098 - val_loss: 0.2871 - val_accuracy: 0.9118
# Epoch 28/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2905 - accuracy: 0.8967 - val_loss: 0.2362 - val_accuracy: 0.9338
# Epoch 29/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2580 - accuracy: 0.9046 - val_loss: 0.2256 - val_accuracy: 0.9338
# Epoch 30/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2475 - accuracy: 0.9020 - val_loss: 0.2147 - val_accuracy: 0.9485
# Epoch 31/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2280 - accuracy: 0.9150 - val_loss: 0.2913 - val_accuracy: 0.8824
# Epoch 32/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2097 - accuracy: 0.9176 - val_loss: 0.2115 - val_accuracy: 0.9044
# Epoch 33/75
# 4/4 [==============================] - 0s 54ms/step - loss: 0.2127 - accuracy: 0.9124 - val_loss: 0.2030 - val_accuracy: 0.9632
# Epoch 34/75
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1967 - accuracy: 0.9242 - val_loss: 0.1761 - val_accuracy: 0.9632
# Epoch 35/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1743 - accuracy: 0.9386 - val_loss: 0.1748 - val_accuracy: 0.9632
# Epoch 36/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1539 - accuracy: 0.9464 - val_loss: 0.2385 - val_accuracy: 0.9338
# Epoch 37/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1589 - accuracy: 0.9556 - val_loss: 0.1776 - val_accuracy: 0.9412
# Epoch 38/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1574 - accuracy: 0.9373 - val_loss: 0.2027 - val_accuracy: 0.9485
# Epoch 39/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1752 - accuracy: 0.9307 - val_loss: 0.1806 - val_accuracy: 0.9559
# Epoch 40/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1289 - accuracy: 0.9595 - val_loss: 0.1698 - val_accuracy: 0.9632
# Epoch 41/75
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1407 - accuracy: 0.9438 - val_loss: 0.1696 - val_accuracy: 0.9632
# Epoch 42/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1265 - accuracy: 0.9621 - val_loss: 0.1770 - val_accuracy: 0.9559
# Epoch 43/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1215 - accuracy: 0.9516 - val_loss: 0.1713 - val_accuracy: 0.9706
# Epoch 44/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1140 - accuracy: 0.9660 - val_loss: 0.1618 - val_accuracy: 0.9632
# Epoch 45/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1070 - accuracy: 0.9686 - val_loss: 0.2087 - val_accuracy: 0.9632
# Epoch 46/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1044 - accuracy: 0.9660 - val_loss: 0.1577 - val_accuracy: 0.9706
# Epoch 47/75
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0994 - accuracy: 0.9699 - val_loss: 0.1543 - val_accuracy: 0.9706
# Epoch 48/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1074 - accuracy: 0.9647 - val_loss: 0.2139 - val_accuracy: 0.9559
# Epoch 49/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1274 - accuracy: 0.9542 - val_loss: 0.2862 - val_accuracy: 0.8897
# Epoch 50/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1545 - accuracy: 0.9359 - val_loss: 0.2231 - val_accuracy: 0.9338
# Epoch 51/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1301 - accuracy: 0.9542 - val_loss: 0.1967 - val_accuracy: 0.9265
# Epoch 52/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1256 - accuracy: 0.9503 - val_loss: 0.1596 - val_accuracy: 0.9706
# Epoch 53/75
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1110 - accuracy: 0.9542 - val_loss: 0.1789 - val_accuracy: 0.9559
# Epoch 54/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0972 - accuracy: 0.9739 - val_loss: 0.2010 - val_accuracy: 0.9338
# Epoch 55/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1096 - accuracy: 0.9595 - val_loss: 0.2043 - val_accuracy: 0.9559
# Epoch 56/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1002 - accuracy: 0.9608 - val_loss: 0.2099 - val_accuracy: 0.9485
# Epoch 57/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0943 - accuracy: 0.9660 - val_loss: 0.1842 - val_accuracy: 0.9412
# Epoch 58/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1022 - accuracy: 0.9660 - val_loss: 0.1946 - val_accuracy: 0.9485
# Epoch 59/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0866 - accuracy: 0.9686 - val_loss: 0.1883 - val_accuracy: 0.9559
# Epoch 60/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0963 - accuracy: 0.9582 - val_loss: 0.2076 - val_accuracy: 0.9338
# Epoch 61/75
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1021 - accuracy: 0.9647 - val_loss: 0.2149 - val_accuracy: 0.9485
# Epoch 62/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0825 - accuracy: 0.9739 - val_loss: 0.1634 - val_accuracy: 0.9485
# Epoch 63/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0728 - accuracy: 0.9752 - val_loss: 0.2362 - val_accuracy: 0.9412
# Epoch 64/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0713 - accuracy: 0.9791 - val_loss: 0.1581 - val_accuracy: 0.9559
# Epoch 65/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0755 - accuracy: 0.9725 - val_loss: 0.1901 - val_accuracy: 0.9706
# Epoch 66/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0628 - accuracy: 0.9752 - val_loss: 0.1757 - val_accuracy: 0.9632
# Epoch 67/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0606 - accuracy: 0.9843 - val_loss: 0.1597 - val_accuracy: 0.9706
# Epoch 68/75
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0536 - accuracy: 0.9843 - val_loss: 0.1751 - val_accuracy: 0.9706
# Epoch 69/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0636 - accuracy: 0.9856 - val_loss: 0.1580 - val_accuracy: 0.9559
# Epoch 70/75
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0562 - accuracy: 0.9882 - val_loss: 0.2199 - val_accuracy: 0.9559
# Epoch 71/75
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0462 - accuracy: 0.9882 - val_loss: 0.1671 - val_accuracy: 0.9706
# Epoch 72/75
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0619 - accuracy: 0.9791 - val_loss: 0.2220 - val_accuracy: 0.9412
# Training completed

# %%
# Model evaluation on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy:.4f}")

y_score = model.predict(X_test)
print("Testing completed")
# Out:
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2535 - accuracy: 0.9159
# Test accuracy: 0.9159
# 8/8 [==============================] - 0s 3ms/step
# Testing completed

# %%
# Define needed variables for plotting
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'Best epoch = {str(index_loss + 1)}'
acc_label = f'Best epoch = {str(index_acc + 1)}'

# %%
plt.figure(figsize=(15, 5))
plt.style.use('default')

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'r', label = 'Train Loss')
plt.plot(history.history['val_loss'][:epochs], 'g', label = 'Val Loss')
plt.scatter(index_loss + 1, val_lowest, 50, 'b',label = loss_label)
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'r', label = 'Train Accuracy')
plt.plot(history.history['val_accuracy'][:epochs], 'g', label = 'Val Accuracy')
plt.scatter(index_acc + 1 , acc_highest, 50, 'b', label = acc_label)
plt.legend()
plt.title('Accuracy')

plt.tight_layout()
plt.show()

# %%
# Get the final confusion matrix 
predicted_labels = np.argmax(y_score, axis=1)
conf_matrix = confusion_matrix(y_test, predicted_labels)

plt.figure(figsize=(8, 6))
plt.style.use('default')
plt.title("Confusion Matrix")
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)

for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, str(conf_matrix[i, j]), ha='center', va='center', color='black', fontsize=12)

plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.show()
